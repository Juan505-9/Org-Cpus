# %% [markdown]
# ![Screen%20Shot%202022-04-20%20at%204.51.59%20PM.png](attachment:Screen%20Shot%202022-04-20%20at%204.51.59%20PM.png)

# %%
Memoria Virtual

# %% [markdown]
# ![Screen%20Shot%202022-04-20%20at%204.57.02%20PM.png](attachment:Screen%20Shot%202022-04-20%20at%204.57.02%20PM.png)

# %% [markdown]
# Memoria Over Allocation

# %% [markdown]
# ![Screen%20Shot%202022-04-20%20at%206.42.42%20PM.png](attachment:Screen%20Shot%202022-04-20%20at%206.42.42%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202022-04-20%20at%206.33.24%20PM.png](attachment:Screen%20Shot%202022-04-20%20at%206.33.24%20PM.png)
